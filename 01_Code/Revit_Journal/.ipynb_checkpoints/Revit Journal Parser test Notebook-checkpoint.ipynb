# %%
import json
import pandas as pd
import csv
import re
# https://docs.python.org/3/library/re.html

# %%
https://regexr.com/

# %%
# %LOCALAPPDATA%\Autodesk\Revit\Autodesk Revit ####\Journals
# Out:
# UsageError: Line magic function `%LOCALAPPDATA%\Autodesk\Revit\Autodesk` not found.

# %%
data = pd.read_csv('C:\\Users\\dgoodwin\\Desktop\\LogFile\\journal.0019.txt', sep="'", header=None)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-17-bb12e07c1c0e> in <module>
# ----> 1 data = pd.read_csv('C:\\Users\\dgoodwin\\Desktop\\LogFile\\journal.0019.txt', sep="'", header=None)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
# ...

# %%
journal_txt = open("C:\\Users\\dgoodwin\\Desktop\\LogFile\\journal.0019.txt", "r")

# %%
print (journal_txt.read())
# Out:
# ' 0:< Initial VM: Avail 134213249 MB, Used 19 MB, Peak 19; RAM: Avail 46947 MB, Used 62 MB, Peak 19
# ' 0:< GUI Resource Usage GDI: Avail 9999, Used 1, User: Used 3
# 'C 26-Jul-2020 21:55:40.163;   0:< started recording journal file
# ' Build: 20190808_0900(x64)
# ' Branch: RELEASE_2019
# ' Release: 2019.2.2
# Dim Jrn
# Set Jrn = CrsJournalScript
# 'C 26-Jul-2020 21:55:40.170;   0:< ->desktop InitApplication
# 'C 26-Jul-2020 21:55:40.183;   0:< <-desktop InitApplication
# 'C 26-Jul-2020 21:55:40.183;   0:< ->desktop InitNativeInstance
# ' 0:< Options::loadOptions: m_strDataLibraryLocations=DLR Library=\\DLRGroup\Data\DesignTech\Revit\Family_Library\2019\,DLR Detail Library=\\DLRGroup\Data\DesignTech\Revit\Family_Library\2019\Detail Components\ (defaultLib==\Library)
# ' 0:< ::0:: Delta VM: Avail -35 -> 134213215 MB, Used +4 -> 23 MB, Peak +4 -> 23 MB; RAM: Avail -64 -> 46884 MB, Used +13 -> 75 MB, Peak +13 -> 75 MB
# ' 0:< GUI Resource Usage GDI: Avail 9983, Used 17, User: Used 28
# ...

# %%
txt = "RegExr was created by gskinner.com, and is proudly hosted by Media Temple."
x = re.findall("([A-Z])\w+", txt)

# %%
x
# Out:
# ['R', 'M', 'T']

# %%
txt = "The rain in Spain"
x = re.search("ai", txt)
print(x)
# Out:
# <re.Match object; span=(5, 7), match='ai'>
